# %%
import random


#initializing all of the variables
x = True
options = [ "rock", "paper", "scissors"]
options2 = ["paper", "scissors"]
options3 = ["paper", "rock"]
options4 = ["scissor", "rock"]
c_choice = random.choice(options)
p_choice = raw_input("Please choose either 'rock', 'paper', 'scissors', or 'quit'.")
p_choice = p_choice.lower()

rocklist = []
paperlist = []
scissorlist = []
winlist=[]


 #game loop, run this until the player wants to quit in which it exits the loop
while x:


	

	if p_choice == "rock":
		rocklist.append(1)
		if c_choice == "rock":
			print "Oh no, the computer picked rock as well, you tied. Please play again"
		elif c_choice == "paper":
			print "Sorry, you lose! The computer picked paper, and paper covers rock! Please play again."
		elif c_choice == "scissors":
			print "Congrats, you win! The computer picked scissors and rock smashes scissors. Play Again."
			winlist.append("1")
	elif p_choice == "paper":
		paperlist.append(1)
		if c_choice == "paper":
			print "Oh no, the computer picked paper as well, you tied. Please play again"
		elif c_choice == "scissors":
			print "Sorry, you lose! The computer picked scissors, and scissors cut paper! Please play again."
		elif c_choice == "rock":
			print "Congrats, you win! The computer picked rock and paper covers rock. Play Again."
			winlist.append("1")
	elif p_choice == "scissors":
		scissorlist.append(1)
		if c_choice == "scissors":
			print "Oh no, the computer picked scissors as well, you tied. Please play again"
		elif c_choice == "rock":
			print "Sorry, you lose! The computer picked rock, and rock smashes scissors! Please play again."
		elif c_choice == "paper":
			print "Congrats, you win! The computer picked paper and scissors cut paper. Play Again."
			winlist.append("1")
	elif p_choice == "quit":
		print "Thank you for playing!"
		totalwins = int(len(winlist))
		totalgames = int(len(rocklist) + len(paperlist) + len(scissorlist))
		print "You played " + str(totalgames) + " games and won " + str(totalwins) + " of them!"
		break
	else:
		print "Invalid entry! Please enter a proper response in all lowercaps!"

quit
        #giving the computer a brain, choosing an ouput for the computer
	if len(rocklist) > (len(paperlist)+len(scissorlist)):
		c_choice = "paper"
	elif len(paperlist) > (len(rocklist) +len(scissorlist)):
		c_choice = "scissors"
	elif len(scissorlist) > (len(rocklist) + len(paperlist)):
		c_choice= "rock"
	elif len(rocklist) == len(paperlist) and (len(rocklist) + len(paperlist)) > len(scissorlist):
		c_choice = random.choice(options2)
	elif len(rocklist) == len(scissorlist) and (len(rocklist) + len(scissorlist)) > len(paperlist):
		c_choice = random.choice(options3)
	elif len(scissorlist) == len(paperlist) and (len(scissorlist) + len(paperlist)) > len(rocklist):
		c_choice = random.choice(options4)
	else:
		c_choice = random.choice(options)

	#getting the users input
	p_choice = raw_input("Please choose either 'rock', 'paper', 'scissors' or 'quit'.")
        #converting input to all lowercase
	p_choice = p_choice.lower()
# Out:
# Please choose either 'rock', 'paper', 'scissors', or 'quit'.rock
# Sorry, you lose! The computer picked paper, and paper covers rock! Please play again.
# Please choose either 'rock', 'paper', 'scissors' or 'quit'.papedr
# Invalid entry! Please enter a proper response in all lowercaps!
# Please choose either 'rock', 'paper', 'scissors' or 'quit'.paper
# Oh no, the computer picked paper as well, you tied. Please play again
# Please choose either 'rock', 'paper', 'scissors' or 'quit'.quit
# Thank you for playing!
# You played 2 games and won 0 of them!
