# %%
from pandas import Series, DataFrame
import pandas as pd

chicago = pd.read_csv('chicago_crimes.csv', dtype = unicode).dropna()

# %%
chicago[:10]
# Out:
#    Unnamed: 0       ID Case Number            Date                  Block  \
# 0     4506608  9878952    HX529642    12/4/14 9:30        010XX E 47TH ST
# 1      561379  2514319    HH857213   12/24/02 9:00  055XX W CONGRESS PKWY
# 2     5058884  3891396    HL266026   3/31/05 11:46    050XX N KIMBALL AVE
# 3     3619502  4983700    HM446634   6/30/06 16:44    034XX W CHICAGO AVE
# 4     5533749  5284225    HM654977  10/11/06 23:05     007XX S CICERO AVE
# 5     6162396  2182182    HH429064     6/9/02 5:00    045XX N ASHLAND AVE
# 6      720409  2839797    HJ500224   7/16/03 17:45  016XX N MAPLEWOOD AVE
# 7     2251410  7313423    HS117845   1/12/10 22:30    015XX S SANGAMON ST
# 9     4676604  3339646    HK381485   5/22/04 19:07       001XX N STATE ST
# 11    5712246  6032714    HP131858    6/11/07 4:00     072XX S PAULINA ST
#
#     IUCR        Primary Type                                     Description  \
# 0    497             BATTERY  AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON
# 1   1320     CRIMINAL DAMAGE                                      TO VEHICLE
# 2   141C   WEAPONS VIOLATION                  UNLAWFUL USE OTHER DANG WEAPON
# 3   2092           NARCOTICS                  SOLICIT NARCOTICS ON PUBLICWAY
# 4   1506        PROSTITUTION                           SOLICIT ON PUBLIC WAY
# 5   1811           NARCOTICS                    POSS: CANNABIS 30GMS OR LESS
# 6    620            BURGLARY                                  UNLAWFUL ENTRY
# 7    810               THEFT                                       OVER $500
# 9    860               THEFT                                    RETAIL THEFT
# 11  1120  DECEPTIVE PRACTICE                                         FORGERY
#
#        Location Description Arrest           ...            Ward  \
# 0                 APARTMENT  FALSE           ...               4
# 1                     OTHER  FALSE           ...              29
# 2   SCHOOL, PUBLIC, GROUNDS   TRUE           ...              39
# 3                  SIDEWALK   TRUE           ...              27
# 4                    STREET   TRUE           ...              24
# 5                    STREET   TRUE           ...              47
# 6             PARK PROPERTY  FALSE           ...               1
# 7                    STREET  FALSE           ...              25
# 9          DEPARTMENT STORE   TRUE           ...              42
# 11                RESIDENCE  FALSE           ...              17
#
#    Community Area FBI Code X Coordinate Y Coordinate  Year    Updated On  \
# 0              39      04B      1183896      1874058  2014   2/4/16 6:33
# 1              25       14      1139530      1897135  2002  4/15/16 8:55
# 2              13       15      1152801      1933422  2005  4/15/16 8:55
# 3              23       26      1153483      1905125  2006  4/15/16 8:55
# 4              25       16      1144509      1896222  2006  4/15/16 8:55
# 5               3       18      1164839      1930205  2002  4/15/16 8:55
# 6              24        5      1159114      1910852  2003  4/15/16 8:55
# 7              28        6      1170443      1892718  2010   2/4/16 6:33
# 9              32        6      1176352      1900927  2004  4/15/16 8:55
# 11             67       10      1166265      1856717  2007  4/15/16 8:55
#
#        Latitude     Longitude                 Location
# 0    41.8095966  -87.60101633  (41.809597, -87.601016)
# 1   41.87384547  -87.76318349  (41.873845, -87.763183)
# 2   41.97316782  -87.71349527  (41.973168, -87.713495)
# 3   41.89550508  -87.71174182  (41.895505, -87.711742)
# 4   41.87124787  -87.74492573  (41.871248, -87.744926)
# 5   41.96409271  -87.66932057  (41.964093, -87.669321)
# 6   41.91110663  -87.69090291  (41.911107, -87.690903)
# 7   41.86110533  -87.64981486  (41.861105, -87.649815)
# 9   41.88350019   -87.6278767    (41.8835, -87.627877)
# 11  41.76240481   -87.6661773  (41.762405, -87.666177)
#
# [10 rows x 23 columns]

# %%
# Group by types of crime, location
chicago_grouped = chicago.groupby(['District', 'Primary Type'])['Primary Type'].count()
chicago_grouped

# Top primary type per district
chicago_unstacked = chicago_grouped.unstack('Primary Type').T.idxmax()
chicago_unstacked
# Out:
# District
# 1         THEFT
# 10      BATTERY
# 11    NARCOTICS
# 12        THEFT
# 14        THEFT
# 15    NARCOTICS
# 16        THEFT
# 17        THEFT
# 18        THEFT
# 19        THEFT
# 2       BATTERY
# 20        THEFT
# 22        THEFT
# 24        THEFT
# 25      BATTERY
# 3       BATTERY
# 4       BATTERY
# 5       BATTERY
# 6       BATTERY
# 7       BATTERY
# 8         THEFT
# 9       BATTERY
# dtype: object

# %% [markdown]
# It is worth noting that Districts 11 and 15 have Narcotics as their top crime. Should additional police resources be placed towards a narcotics task force for those districts? How are they currently fighting narcotics?

# %%
chicago_grouped2 = chicago.groupby(['Primary Type', 'Description', 'District'])['Description'].count()
chicago_grouped2.sort_values(ascending=False)[:20]
# Out:
# Primary Type     Description              District
# BATTERY          DOMESTIC BATTERY SIMPLE  7           409
#                                           11          383
#                                           6           355
#                                           8           334
#                                           25          328
#                                           4           318
# THEFT            FROM BUILDING            18          314
# BATTERY          DOMESTIC BATTERY SIMPLE  3           309
# THEFT            $500 AND UNDER           12          309
# BATTERY          DOMESTIC BATTERY SIMPLE  15          293
#                                           5           268
# THEFT            $500 AND UNDER           19          259
#                                           14          259
#                  FROM BUILDING            1           257
#                  OVER $500                12          255
#                  $500 AND UNDER           25          254
#                                           8           253
# BATTERY          DOMESTIC BATTERY SIMPLE  9           252
# NARCOTICS        POSS: HEROIN(WHITE)      11          251
# CRIMINAL DAMAGE  TO VEHICLE               8           249
# Name: Description, dtype: int64

# %%
district_mask = chicago['District']

cross_tab = pd.crosstab(chicago['Primary Type'][district_mask], chicago['Description'][district_mask])
cross_tab
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from matplotlib import pyplot as plt
# %pylab inline

crimes_per_district = chicago['District'].value_counts()
crimes_per_district.plot(kind = 'bar')
plt.xlabel('District')
plt.ylabel('Frequency')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# There is not one district that really stands out well beyond the others, but District 8 and 11 do lead when performing value_counts(). In doing additional research, District 8 houses Chicago Midway Airport, so does more crime occur near the airport? Maybe criminals are taking advantage and performing minor crimes on tourists? District 11 includes Garfield Park.

# %%
# Grouping by district and year to see crime over time
chicago_grouped3 = chicago.groupby(['District', 'Year'])['Primary Type'].count()
df = chicago_grouped3.unstack()
df.index = df.index.map(int)
df.sort_index(inplace=True)
del df['2001']
del df['2017']
df
# Out:
# Year       2002   2003   2004   2005   2006   2007   2008   2009   2010  \
# District
# 1         125.0  170.0  153.0  175.0  175.0  155.0  159.0  125.0   92.0
    name = "Crime per Year",
    line = dict(color = '#17BECF'),
    opacity = 0.8)

data = [trace]

# layout = dict(
#     title='Crime per District by Year (2002-2016)',
#     xaxis=dict(
#         rangeselector=dict(
#             buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=6,
#                      label='6m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(step='all')
#             ])
#         ),
#         rangeslider=dict(),
#         type='date'
#     )
# )

fig = dict(data=data)
py.iplot(fig, filename = "Crime per District by Year (2002-2016)")
# Out:
# Aw, snap! We don't have an account for ''. Want to try again? You can authenticate with your email address or username. Sign in is not case sensitive.
#
# Don't have an account? plot.ly
#
# Questions? support@plot.ly
# ---------------------------------------------------------------------------
# PlotlyError                               Traceback (most recent call last)
# <ipython-input-9-24ece5cef417> in <module>()
#      36
#      37 fig = dict(data=data)
# ---> 38 py.iplot(fig, filename = "Crime per District by Year (2002-2016)")
#
# /Users/timothylai/anaconda/lib/python2.7/site-packages/plotly/plotly/plotly.pyc in iplot(figure_or_data, **plot_options)
#     157         embed_options['height'] = str(embed_options['height']) + 'px'
#     158
# --> 159     return tools.embed(url, **embed_options)
#     160
#     161
#
# /Users/timothylai/anaconda/lib/python2.7/site-packages/plotly/tools.pyc in embed(file_owner_or_url, file_id, width, height)
#     388         else:
#     389             url = file_owner_or_url
# --> 390         return PlotlyDisplay(url, width, height)
#     391     else:
#     392         if (get_config_defaults()['plotly_domain']
#
# /Users/timothylai/anaconda/lib/python2.7/site-packages/plotly/tools.pyc in __init__(self, url, width, height)
#    1363         def __init__(self, url, width, height):
#    1364             self.resource = url
# -> 1365             self.embed_code = get_embed(url, width=width, height=height)
#    1366             super(PlotlyDisplay, self).__init__(data=self.embed_code)
#    1367
#
# /Users/timothylai/anaconda/lib/python2.7/site-packages/plotly/tools.pyc in get_embed(file_owner_or_url, file_id, width, height)
#     293                 "'{1}'."
#     294                 "\nRun help on this function for more information."
# --> 295                 "".format(url, plotly_rest_url))
#     296         urlsplit = six.moves.urllib.parse.urlparse(url)
#     297         file_owner = urlsplit.path.split('/')[1].split('~')[1]
#
# PlotlyError: Because you didn't supply a 'file_id' in the call, we're assuming you're trying to snag a figure from a url. You supplied the url, '', we expected it to start with 'https://plot.ly'.
# Run help on this function for more information.

# %%
df_transposed = df.T
df_transposed.sum()
df_copy = df_transposed.copy()
df_copy['Sums'] = df_transposed.sum()
df_copy
# df_transposed
# df_transposed['Total'] = df_transposed.sum()
# df_transposed
# pylab.rcParams['figure.figsize'] =(14,10)
# df_transposed.plot()
# Out:
# District       1       2       3       4       5       6       7       8  \
# Year
# 2002       125.0   219.0   178.0   171.0   158.0   201.0   229.0   230.0
# 2003       170.0   248.0   233.0   280.0   186.0   249.0   272.0   328.0
# 2004       153.0   243.0   241.0   277.0   211.0   248.0   250.0   285.0
# 2005       175.0   213.0   230.0   250.0   211.0   246.0   246.0   305.0
# 2006       175.0   210.0   222.0   262.0   190.0   239.0   280.0   330.0
# 2007       155.0   180.0   245.0   283.0   206.0   271.0   287.0   313.0
# 2008       159.0   197.0   217.0   258.0   199.0   252.0   282.0   330.0
# 2009       125.0   152.0   223.0   222.0   191.0   241.0   205.0   257.0
# 2010        92.0   159.0   208.0   213.0   168.0   237.0   218.0   293.0
# 2011        99.0   123.0   209.0   222.0   152.0   201.0   212.0   234.0
# 2012       120.0   135.0   187.0   205.0   186.0   185.0   207.0   242.0
# 2013       137.0   138.0   170.0   179.0   160.0   191.0   168.0   179.0
# 2014       136.0   122.0   139.0   163.0   128.0   153.0   137.0   190.0
# 2015       119.0   108.0   117.0   131.0    94.0   155.0   143.0   162.0
# 2016       130.0    86.0   113.0   149.0   122.0   159.0   131.0   183.0
# Sums      4140.0  5066.0  5864.0  6530.0  5124.0  6456.0  6534.0  7722.0
#
# District       9      10  ...       15      16      17      18      19  \
# Year                      ...
# 2002       164.0   120.0  ...    135.0   102.0    91.0   175.0   161.0
# 2003       251.0   182.0  ...    199.0   139.0   142.0   213.0   219.0
# 2004       224.0   168.0  ...    193.0   140.0   125.0   218.0   199.0
# 2005       254.0   181.0  ...    197.0   140.0   141.0   175.0   204.0
# 2006       241.0   180.0  ...    196.0   139.0   126.0   186.0   201.0
# 2007       235.0   156.0  ...    172.0   126.0   125.0   174.0   189.0
# 2008       192.0   169.0  ...    169.0   148.0   111.0   162.0   199.0
# 2009       185.0   129.0  ...    199.0   114.0   119.0   150.0   197.0
# 2010       183.0   176.0  ...    195.0   110.0   113.0   168.0   142.0
# 2011       186.0   137.0  ...    147.0   103.0   100.0   140.0   163.0
# 2012       160.0   128.0  ...    136.0    85.0   104.0   147.0   147.0
# 2013       152.0   137.0  ...    120.0   117.0    71.0   141.0   152.0
# 2014       142.0   135.0  ...    129.0   102.0    69.0   108.0   115.0
# 2015       121.0   125.0  ...    124.0    78.0    78.0   109.0   110.0
# 2016       103.0   126.0  ...    125.0    89.0    69.0   130.0   120.0
# Sums      5586.0  4498.0  ...   4872.0  3464.0  3168.0  4792.0  5036.0
#
# District      20      22      24      25  Sums
# Year
# 2002        63.0   128.0   114.0   198.0   NaN
# 2003        88.0   152.0   145.0   261.0   NaN
# 2004        84.0   128.0   132.0   229.0   NaN
# 2005        94.0   162.0   151.0   267.0   NaN
# 2006        70.0   139.0   153.0   243.0   NaN
# 2007        87.0   152.0   130.0   263.0   NaN
# 2008        74.0   135.0   120.0   262.0   NaN
# 2009        57.0   139.0   123.0   263.0   NaN
# 2010        57.0   126.0   102.0   243.0   NaN
# 2011        55.0   118.0    91.0   223.0   NaN
# 2012        44.0   119.0   103.0   192.0   NaN
# 2013        47.0   106.0    99.0   169.0   NaN
# 2014        43.0    90.0    70.0   160.0   NaN
# 2015        47.0    79.0    75.0   151.0   NaN
# 2016        33.0    78.0    83.0   154.0   NaN
# Sums      1886.0  3702.0  3382.0  6556.0   NaN
#
# [16 rows x 23 columns]

# %%
mask = chicago['District']
dist_8 = chicago[mask == '8']
dist_11 = chicago[mask == '11']
dist_25 = chicago[mask == '25']
dist_7 = chicago[mask == '7']
dist_4 = chicago[mask == '4']
